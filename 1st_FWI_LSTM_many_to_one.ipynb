# %%
import torch
import torchvision

import pandas as pd
import numpy as np

# %% [markdown]
# # Seed

# %%
seed_number = 44

torch.manual_seed(seed_number)
torch.cuda.manual_seed(seed_number)
torch.cuda.manual_seed_all(seed_number) # if use multi-GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed_number)
#random.seed(seed_number)

# %% [markdown]
# # Data Load

# %%
#df = pd.read_csv('./data/fwi_peru.csv')
df = pd.read_csv('https://raw.githubusercontent.com/Rackhun/AI-programming-course/refs/heads/main/data/fwi_peru.csv')

print(df.shape)
df.head()
# Out:
# (7670, 8)
#          date       fwi    fbupinx    drtcode   dufmcode    ffmcode    fdsrte  \
# 0  2003-01-01  3.032478  43.350230  303.92447  28.816147  59.494816  0.821229
# 1  2003-01-02  3.234723  43.817448  306.08072  29.067446  58.859665  0.910691
# 2  2003-01-03  3.840679  44.936455  309.48050  29.878538  64.760050  1.050648
# 3  2003-01-04  4.291818  45.781628  312.24307  30.441364  65.765340  1.283834
# 4  2003-01-05  4.434349  46.758377  315.64978  31.114819  65.916730  1.326426
#
#     infsinx
# 0  1.228552
# 1  1.194067
# 2  1.604336
# 3  1.759281
# 4  1.818198

# %%
df.tail()
# Out:
#             date       fwi    fbupinx    drtcode   dufmcode    ffmcode  \
# 7665  2023-12-27  2.525733  36.758522  257.50085  24.618862  35.218212
# 7666  2023-12-28  1.647023  30.309649  242.49062  19.879116  40.500847
# 7667  2023-12-29  1.403245  26.050838  236.74654  16.661034  49.327080
# 7668  2023-12-30  1.826561  25.967650  236.96635  16.680098  53.704983
# 7669  2023-12-31  1.933431  24.840988  231.64226  15.873484  38.895653
#
#         fdsrte   infsinx
# 7665  0.861941  0.750828
# 7666  0.516756  0.528351
# 7667  0.337519  0.615339
# 7668  0.466286  0.831606
# 7669  0.583733  0.600974

# %%
df.dtypes
# Out:
# date         object
# fwi         float64
# fbupinx     float64
# drtcode     float64
# dufmcode    float64
# ffmcode     float64
# fdsrte      float64
# infsinx     float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# date        datetime64[ns]
# fwi                float64
# fbupinx            float64
# drtcode            float64
# dufmcode           float64
# ffmcode            float64
# fdsrte             float64
# infsinx            float64
# dtype: object

# %%
df_train = df[df['date'].dt.year < 2019]
df_test  = df[df['date'].dt.year >= 2019]

print(df_train.shape)
print(df_test.shape)
# Out:
# (5844, 8)
# (1826, 8)

# %%
X = df_train[['fwi', 'fbupinx', 'drtcode', 'dufmcode', 'ffmcode', 'fdsrte', 'infsinx']].values
y = df_train['fwi'].values

X_test = df_test[['fwi', 'fbupinx', 'drtcode', 'dufmcode', 'ffmcode', 'fdsrte', 'infsinx']].values
y_test = df_test['fwi'].values

print(X.shape, y.shape)
print(X_test.shape, y_test.shape)
# Out:
# (5844, 7) (5844,)
# (1826, 7) (1826,)

# %% [markdown]
# # Normalization

# %%
X_max = np.max(X, axis=0)
X_min = np.min(X, axis=0)

X      = (X      - X_min) / (X_max - X_min + 1e-10)
X_test = (X_test - X_min) / (X_max - X_min + 1e-10)

# %%
print(np.max(X), np.min(X))
print(np.max(X_test), np.min(X_test))
# Out:
# 0.9999999999997156 0.0
# 1.1532220684416759 0.00043293813048260325

# %% [markdown]
# # Data organize (sequence)

# %%
sequence_length = 4

# %%
def make_sequence(data, sequence_length):
    data_seq = []
    for i in range(len(data)-sequence_length):
        data_seq.append(data[i:i+sequence_length])
            
    data_seq = np.stack(data_seq, axis=0)    
    return data_seq

# %%
X_seq = make_sequence(X[:-1], sequence_length=sequence_length)
X_test = make_sequence(X_test[:-1], sequence_length=sequence_length)

y_seq = y[sequence_length+1:]
y_test = y_test[sequence_length+1:]

print(X_seq.shape)
print(y_seq.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (5839, 4, 7)
# (5839,)
# (1821, 4, 7)
# (1821,)

# %% [markdown]
# # Split data

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_seq, y_seq, test_size=0.2, random_state=seed_number)

print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
# Out:
# (4671, 4, 7) (4671,)
# (1168, 4, 7) (1168,)

# %% [markdown]
# # Data loader

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

X_train = torch.FloatTensor(X_train).to(device=device)
X_valid = torch.FloatTensor(X_valid).to(device=device)
X_test  = torch.FloatTensor(X_test).to(device=device)

y_train = torch.FloatTensor(y_train).to(device=device)
y_valid = torch.FloatTensor(y_valid).to(device=device)
y_test  = torch.FloatTensor(y_test).to(device=device)
# Out:
# cpu

# %%
train_ds = torch.utils.data.TensorDataset(X_train, y_train)
valid_ds = torch.utils.data.TensorDataset(X_valid, y_valid)

train_loader = torch.utils.data.DataLoader(train_ds, batch_size=128, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_ds, batch_size=128, shuffle=False)

# %% [markdown]
# # Model (many to one)

# %%
class Net(torch.nn.Module):
    def __init__(self, n_input, n_hidden, n_layer):
        super(Net, self).__init__()
        
        self.n_input = n_input
        self.n_hidden = n_hidden
        self.n_layer = n_layer
        
        # https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html
        self.LSTM = torch.nn.LSTM(
            n_input, n_hidden, n_layer, 
            bidirectional=False,
            batch_first=True
        )
        
        self.fully_connected_layer = torch.nn.Linear(32, 1)
        
    def forward(self, xb):
        h_init = torch.zeros(self.n_layer, xb.size()[0], self.n_hidden)
        c_init = torch.zeros(self.n_layer, xb.size()[0], self.n_hidden)
        out, _ = self.LSTM(xb, (h_init, c_init))
        
        out = self.fully_connected_layer(out[:,-1,:])
        return out

# %%
model = Net(
    n_input=7,
    n_hidden=32,
    n_layer=1,
).to(device)
print(model)
# Out:
# Net(
#   (LSTM): LSTM(7, 32, batch_first=True)
#   (fully_connected_layer): Linear(in_features=32, out_features=1, bias=True)
# )

# %% [markdown]
# # Cost function

# %%
criterion = torch.nn.MSELoss()

# %% [markdown]
# # Optimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # Training

# %%
import time 

is_train = True
epoch, early_stopping = 0, 0
train_loss_history, valid_loss_history = [], []

while is_train:
    start = time.time()
    train_loss, train_count = 0., 0.
    epoch += 1
    early_stopping += 1
    
    for xb, yb in train_loader:
        prediction = model(xb)
        loss = criterion(prediction[:,0], yb)
        train_loss += loss.item()*len(yb)
        train_count += len(yb)
        
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    with torch.no_grad():
        valid_loss = 0
        valid_count = 0.
        
        for xb, yb in valid_loader:
            prediction = model(xb)
            valid_loss += criterion(prediction[:,0], yb)*len(yb)
            valid_count += len(yb)
        
    train_loss /= train_count
    valid_loss /= valid_count    
    
    train_loss_history.append(train_loss)
    valid_loss_history.append(valid_loss)
    
    if min(valid_loss_history) == valid_loss:
        early_stopping = 0
        
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': valid_loss,
        }, './saved_model.pt')
        
    if early_stopping == 30:
        is_train = False
            
    print(f"======== Epoch {epoch} =======")
    print(f"Loss => train:{train_loss:.5f}, valid:{valid_loss:.5f}, Elapsed time => {time.time()-start:.3f} sec")
    print("=======================================\n")
# Out:
# ======== Epoch 1 =======
# Loss => train:31.25969, valid:29.43158, Elapsed time => 0.238 sec
# =======================================
#
# ======== Epoch 2 =======
# Loss => train:17.53183, valid:11.13086, Elapsed time => 0.201 sec
# =======================================
#
# ======== Epoch 3 =======
# Loss => train:7.31470, valid:7.15764, Elapsed time => 0.199 sec
# =======================================
#
# ======== Epoch 4 =======
# Loss => train:5.35729, valid:5.41342, Elapsed time => 0.200 sec
# =======================================
#
# ======== Epoch 5 =======
# Loss => train:3.88183, valid:4.04242, Elapsed time => 0.199 sec
# =======================================
#
# ======== Epoch 6 =======
# Loss => train:3.00933, valid:3.30634, Elapsed time => 0.224 sec
# =======================================
#
# ======== Epoch 7 =======
# Loss => train:2.54671, valid:2.82804, Elapsed time => 0.233 sec
# =======================================
#
# ======== Epoch 8 =======
# Loss => train:2.21972, valid:2.47383, Elapsed time => 0.200 sec
# =======================================
#
# ======== Epoch 9 =======
# Loss => train:2.01344, valid:2.23836, Elapsed time => 0.208 sec
# =======================================
#
# ======== Epoch 10 =======
# Loss => train:1.87890, valid:2.10929, Elapsed time => 0.220 sec
# =======================================
#
# ======== Epoch 11 =======
# Loss => train:1.79210, valid:1.98206, Elapsed time => 0.227 sec
# =======================================
#
# ======== Epoch 12 =======
# Loss => train:1.73818, valid:1.90209, Elapsed time => 0.228 sec
# =======================================
#
# ======== Epoch 13 =======
# Loss => train:1.67700, valid:1.83540, Elapsed time => 0.233 sec
# =======================================
#
# ======== Epoch 14 =======
# Loss => train:1.62832, valid:1.77559, Elapsed time => 0.221 sec
# =======================================
#
# ======== Epoch 15 =======
# Loss => train:1.57815, valid:1.71969, Elapsed time => 0.221 sec
# =======================================
#
# ======== Epoch 16 =======
# Loss => train:1.53662, valid:1.67152, Elapsed time => 0.228 sec
# =======================================
#
# ======== Epoch 17 =======
# Loss => train:1.50626, valid:1.63444, Elapsed time => 0.219 sec
# =======================================
#
# ======== Epoch 18 =======
# Loss => train:1.48757, valid:1.68993, Elapsed time => 0.211 sec
# =======================================
#
# ======== Epoch 19 =======
# Loss => train:1.46597, valid:1.57185, Elapsed time => 0.208 sec
# =======================================
#
# ======== Epoch 20 =======
# Loss => train:1.42744, valid:1.54291, Elapsed time => 0.197 sec
# =======================================
#
# ======== Epoch 21 =======
# Loss => train:1.40153, valid:1.53081, Elapsed time => 0.200 sec
# =======================================
#
# ======== Epoch 22 =======
# Loss => train:1.39702, valid:1.53913, Elapsed time => 0.199 sec
# =======================================
#
# ======== Epoch 23 =======
# Loss => train:1.38903, valid:1.48881, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 24 =======
# Loss => train:1.35290, valid:1.46130, Elapsed time => 0.209 sec
# =======================================
#
# ======== Epoch 25 =======
# Loss => train:1.33913, valid:1.44483, Elapsed time => 0.217 sec
# =======================================
#
# ======== Epoch 26 =======
# Loss => train:1.33228, valid:1.42093, Elapsed time => 0.204 sec
# =======================================
#
# ======== Epoch 27 =======
# Loss => train:1.30913, valid:1.45542, Elapsed time => 0.199 sec
# =======================================
#
# ======== Epoch 28 =======
# Loss => train:1.29764, valid:1.39151, Elapsed time => 0.198 sec
# =======================================
#
# ======== Epoch 29 =======
# Loss => train:1.28048, valid:1.39128, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 30 =======
# Loss => train:1.26577, valid:1.36462, Elapsed time => 0.216 sec
# =======================================
#
# ======== Epoch 31 =======
# Loss => train:1.26334, valid:1.35409, Elapsed time => 0.222 sec
# =======================================
#
# ======== Epoch 32 =======
# Loss => train:1.23898, valid:1.32813, Elapsed time => 0.198 sec
# =======================================
#
# ======== Epoch 33 =======
# Loss => train:1.23683, valid:1.33586, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 34 =======
# Loss => train:1.22341, valid:1.30601, Elapsed time => 0.219 sec
# =======================================
#
# ======== Epoch 35 =======
# Loss => train:1.20992, valid:1.30283, Elapsed time => 0.226 sec
# =======================================
#
# ======== Epoch 36 =======
# Loss => train:1.19898, valid:1.34208, Elapsed time => 0.221 sec
# =======================================
#
# ======== Epoch 37 =======
# Loss => train:1.19627, valid:1.27234, Elapsed time => 0.213 sec
# =======================================
#
# ======== Epoch 38 =======
# Loss => train:1.17937, valid:1.27485, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 39 =======
# Loss => train:1.16335, valid:1.24177, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 40 =======
# Loss => train:1.15193, valid:1.23731, Elapsed time => 0.213 sec
# =======================================
#
# ======== Epoch 41 =======
# Loss => train:1.13742, valid:1.22058, Elapsed time => 0.208 sec
# =======================================
#
# ======== Epoch 42 =======
# Loss => train:1.12856, valid:1.20631, Elapsed time => 0.209 sec
# =======================================
#
# ======== Epoch 43 =======
# Loss => train:1.12314, valid:1.20669, Elapsed time => 0.196 sec
# =======================================
#
# ======== Epoch 44 =======
# Loss => train:1.11249, valid:1.18318, Elapsed time => 0.204 sec
# =======================================
#
# ======== Epoch 45 =======
# Loss => train:1.11008, valid:1.23371, Elapsed time => 0.204 sec
# =======================================
#
# ======== Epoch 46 =======
# Loss => train:1.09497, valid:1.16867, Elapsed time => 0.199 sec
# =======================================
#
# ======== Epoch 47 =======
# Loss => train:1.08461, valid:1.16365, Elapsed time => 0.202 sec
# =======================================
#
# ======== Epoch 48 =======
# Loss => train:1.08395, valid:1.15179, Elapsed time => 0.202 sec
# =======================================
#
# ======== Epoch 49 =======
# Loss => train:1.07429, valid:1.13027, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 50 =======
# Loss => train:1.06234, valid:1.12488, Elapsed time => 0.215 sec
# =======================================
#
# ======== Epoch 51 =======
# Loss => train:1.04771, valid:1.12006, Elapsed time => 0.200 sec
# =======================================
#
# ======== Epoch 52 =======
# Loss => train:1.05249, valid:1.11020, Elapsed time => 0.201 sec
# =======================================
#
# ======== Epoch 53 =======
# Loss => train:1.04716, valid:1.09197, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 54 =======
# Loss => train:1.04991, valid:1.11940, Elapsed time => 0.201 sec
# =======================================
#
# ======== Epoch 55 =======
# Loss => train:1.03060, valid:1.07585, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 56 =======
# Loss => train:1.03311, valid:1.08423, Elapsed time => 0.200 sec
# =======================================
#
# ======== Epoch 57 =======
# Loss => train:1.01521, valid:1.06392, Elapsed time => 0.207 sec
# =======================================
#
# ======== Epoch 58 =======
# Loss => train:1.00756, valid:1.08834, Elapsed time => 0.209 sec
# =======================================
#
# ======== Epoch 59 =======
# Loss => train:0.99771, valid:1.07141, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 60 =======
# Loss => train:0.99284, valid:1.05508, Elapsed time => 0.215 sec
# =======================================
#
# ======== Epoch 61 =======
# Loss => train:1.01971, valid:1.03705, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 62 =======
# Loss => train:0.99260, valid:1.03318, Elapsed time => 0.223 sec
# =======================================
#
# ======== Epoch 63 =======
# Loss => train:0.98370, valid:1.12470, Elapsed time => 0.217 sec
# =======================================
#
# ======== Epoch 64 =======
# Loss => train:0.99114, valid:1.02561, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 65 =======
# Loss => train:0.97092, valid:1.01869, Elapsed time => 0.228 sec
# =======================================
#
# ======== Epoch 66 =======
# Loss => train:0.96093, valid:1.03817, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 67 =======
# Loss => train:0.98133, valid:1.05231, Elapsed time => 0.204 sec
# =======================================
#
# ======== Epoch 68 =======
# Loss => train:0.97774, valid:1.01851, Elapsed time => 0.208 sec
# =======================================
#
# ======== Epoch 69 =======
# Loss => train:0.95373, valid:1.00260, Elapsed time => 0.198 sec
# =======================================
#
# ======== Epoch 70 =======
# Loss => train:0.95979, valid:1.00145, Elapsed time => 0.213 sec
# =======================================
#
# ======== Epoch 71 =======
# Loss => train:0.94877, valid:1.02073, Elapsed time => 0.221 sec
# =======================================
#
# ======== Epoch 72 =======
# Loss => train:0.95981, valid:1.10687, Elapsed time => 0.204 sec
# =======================================
#
# ======== Epoch 73 =======
# Loss => train:0.97157, valid:1.09870, Elapsed time => 0.208 sec
# =======================================
#
# ======== Epoch 74 =======
# Loss => train:0.96082, valid:1.03789, Elapsed time => 0.200 sec
# =======================================
#
# ======== Epoch 75 =======
# Loss => train:0.93988, valid:0.98315, Elapsed time => 0.199 sec
# =======================================
#
# ======== Epoch 76 =======
# Loss => train:0.95330, valid:0.98030, Elapsed time => 0.200 sec
# =======================================
#
# ======== Epoch 77 =======
# Loss => train:0.92798, valid:0.98228, Elapsed time => 0.196 sec
# =======================================
#
# ======== Epoch 78 =======
# Loss => train:0.93596, valid:0.98538, Elapsed time => 0.196 sec
# =======================================
#
# ======== Epoch 79 =======
# Loss => train:0.93011, valid:0.97072, Elapsed time => 0.193 sec
# =======================================
#
# ======== Epoch 80 =======
# Loss => train:0.94095, valid:0.97334, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 81 =======
# Loss => train:0.92776, valid:0.98993, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 82 =======
# Loss => train:0.94425, valid:0.96626, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 83 =======
# Loss => train:0.92259, valid:0.98206, Elapsed time => 0.209 sec
# =======================================
#
# ======== Epoch 84 =======
# Loss => train:0.92174, valid:0.99126, Elapsed time => 0.201 sec
# =======================================
#
# ======== Epoch 85 =======
# Loss => train:0.93721, valid:1.04230, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 86 =======
# Loss => train:0.94759, valid:0.98545, Elapsed time => 0.201 sec
# =======================================
#
# ======== Epoch 87 =======
# Loss => train:0.91139, valid:0.95879, Elapsed time => 0.203 sec
# =======================================
#
# ======== Epoch 88 =======
# Loss => train:0.92035, valid:0.96374, Elapsed time => 0.213 sec
# =======================================
#
# ======== Epoch 89 =======
# Loss => train:0.90844, valid:0.96350, Elapsed time => 0.211 sec
# =======================================
#
# ======== Epoch 90 =======
# Loss => train:0.91884, valid:0.97481, Elapsed time => 0.211 sec
# =======================================
#
# ======== Epoch 91 =======
# Loss => train:0.91442, valid:0.96641, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 92 =======
# Loss => train:0.92378, valid:0.97851, Elapsed time => 0.212 sec
# =======================================
#
# ======== Epoch 93 =======
# Loss => train:0.91964, valid:0.95942, Elapsed time => 0.207 sec
# =======================================
#
# ======== Epoch 94 =======
# Loss => train:0.91367, valid:0.96289, Elapsed time => 0.215 sec
# =======================================
#
# ======== Epoch 95 =======
# Loss => train:0.90563, valid:0.96439, Elapsed time => 0.209 sec
# =======================================
#
# ======== Epoch 96 =======
# Loss => train:0.91420, valid:0.95109, Elapsed time => 0.209 sec
# =======================================
#
# ======== Epoch 97 =======
# Loss => train:0.91518, valid:0.95426, Elapsed time => 0.220 sec
# =======================================
#
# ======== Epoch 98 =======
# Loss => train:0.90062, valid:1.01708, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 99 =======
# Loss => train:0.96424, valid:0.95331, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 100 =======
# Loss => train:0.90433, valid:0.97362, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 101 =======
# Loss => train:0.90612, valid:0.96135, Elapsed time => 0.202 sec
# =======================================
#
# ======== Epoch 102 =======
# Loss => train:0.90389, valid:0.94860, Elapsed time => 0.202 sec
# =======================================
#
# ======== Epoch 103 =======
# Loss => train:0.89698, valid:0.94618, Elapsed time => 0.221 sec
# =======================================
#
# ======== Epoch 104 =======
# Loss => train:0.89085, valid:0.95036, Elapsed time => 0.219 sec
# =======================================
#
# ======== Epoch 105 =======
# Loss => train:0.90752, valid:0.95647, Elapsed time => 0.237 sec
# =======================================
#
# ======== Epoch 106 =======
# Loss => train:0.94493, valid:0.96136, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 107 =======
# Loss => train:0.90014, valid:0.96078, Elapsed time => 0.207 sec
# =======================================
#
# ======== Epoch 108 =======
# Loss => train:0.89304, valid:0.94919, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 109 =======
# Loss => train:0.91070, valid:0.96974, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 110 =======
# Loss => train:0.89706, valid:0.98357, Elapsed time => 0.211 sec
# =======================================
#
# ======== Epoch 111 =======
# Loss => train:0.89437, valid:0.94560, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 112 =======
# Loss => train:0.89810, valid:0.99765, Elapsed time => 0.209 sec
# =======================================
#
# ======== Epoch 113 =======
# Loss => train:0.89269, valid:0.94334, Elapsed time => 0.222 sec
# =======================================
#
# ======== Epoch 114 =======
# Loss => train:0.89947, valid:0.95718, Elapsed time => 0.221 sec
# =======================================
#
# ======== Epoch 115 =======
# Loss => train:0.91115, valid:0.95083, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 116 =======
# Loss => train:0.90489, valid:0.95017, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 117 =======
# Loss => train:0.89069, valid:1.01503, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 118 =======
# Loss => train:0.88525, valid:0.96009, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 119 =======
# Loss => train:0.89282, valid:0.94427, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 120 =======
# Loss => train:0.89406, valid:0.95724, Elapsed time => 0.211 sec
# =======================================
#
# ======== Epoch 121 =======
# Loss => train:0.90338, valid:0.96688, Elapsed time => 0.211 sec
# =======================================
#
# ======== Epoch 122 =======
# Loss => train:0.92001, valid:0.97288, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 123 =======
# Loss => train:0.89894, valid:1.01415, Elapsed time => 0.215 sec
# =======================================
#
# ======== Epoch 124 =======
# Loss => train:0.90715, valid:1.00954, Elapsed time => 0.218 sec
# =======================================
#
# ======== Epoch 125 =======
# Loss => train:0.88729, valid:0.95984, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 126 =======
# Loss => train:0.88301, valid:0.98758, Elapsed time => 0.222 sec
# =======================================
#
# ======== Epoch 127 =======
# Loss => train:0.88945, valid:0.95910, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 128 =======
# Loss => train:0.88083, valid:0.93902, Elapsed time => 0.219 sec
# =======================================
#
# ======== Epoch 129 =======
# Loss => train:0.89348, valid:0.94379, Elapsed time => 0.208 sec
# =======================================
#
# ======== Epoch 130 =======
# Loss => train:0.87826, valid:0.96467, Elapsed time => 0.207 sec
# =======================================
#
# ======== Epoch 131 =======
# Loss => train:0.88345, valid:0.99992, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 132 =======
# Loss => train:0.88423, valid:0.94008, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 133 =======
# Loss => train:0.87855, valid:0.93895, Elapsed time => 0.212 sec
# =======================================
#
# ======== Epoch 134 =======
# Loss => train:0.89578, valid:0.93924, Elapsed time => 0.200 sec
# =======================================
#
# ======== Epoch 135 =======
# Loss => train:0.88416, valid:0.95653, Elapsed time => 0.194 sec
# =======================================
#
# ======== Epoch 136 =======
# Loss => train:0.88489, valid:0.93817, Elapsed time => 0.203 sec
# =======================================
#
# ======== Epoch 137 =======
# Loss => train:0.87539, valid:0.97995, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 138 =======
# Loss => train:0.94277, valid:0.97443, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 139 =======
# Loss => train:0.90111, valid:0.96562, Elapsed time => 0.209 sec
# =======================================
#
# ======== Epoch 140 =======
# Loss => train:0.88285, valid:0.93681, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 141 =======
# Loss => train:0.87611, valid:0.93655, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 142 =======
# Loss => train:0.87961, valid:0.95354, Elapsed time => 0.217 sec
# =======================================
#
# ======== Epoch 143 =======
# Loss => train:0.88066, valid:0.93636, Elapsed time => 0.235 sec
# =======================================
#
# ======== Epoch 144 =======
# Loss => train:0.89313, valid:0.97802, Elapsed time => 0.211 sec
# =======================================
#
# ======== Epoch 145 =======
# Loss => train:0.88670, valid:0.95329, Elapsed time => 0.203 sec
# =======================================
#
# ======== Epoch 146 =======
# Loss => train:0.87290, valid:0.95143, Elapsed time => 0.203 sec
# =======================================
#
# ======== Epoch 147 =======
# Loss => train:0.89332, valid:0.94604, Elapsed time => 0.223 sec
# =======================================
#
# ======== Epoch 148 =======
# Loss => train:0.87575, valid:0.93816, Elapsed time => 0.233 sec
# =======================================
#
# ======== Epoch 149 =======
# Loss => train:0.87884, valid:0.94144, Elapsed time => 0.238 sec
# =======================================
#
# ======== Epoch 150 =======
# Loss => train:0.88865, valid:0.94879, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 151 =======
# Loss => train:0.88015, valid:0.93773, Elapsed time => 0.220 sec
# =======================================
#
# ======== Epoch 152 =======
# Loss => train:0.87614, valid:0.93974, Elapsed time => 0.230 sec
# =======================================
#
# ======== Epoch 153 =======
# Loss => train:0.86768, valid:0.94174, Elapsed time => 0.239 sec
# =======================================
#
# ======== Epoch 154 =======
# Loss => train:0.88063, valid:0.98575, Elapsed time => 0.215 sec
# =======================================
#
# ======== Epoch 155 =======
# Loss => train:0.88726, valid:0.93569, Elapsed time => 0.227 sec
# =======================================
#
# ======== Epoch 156 =======
# Loss => train:0.87416, valid:0.93787, Elapsed time => 0.226 sec
# =======================================
#
# ======== Epoch 157 =======
# Loss => train:0.87033, valid:0.95032, Elapsed time => 0.203 sec
# =======================================
#
# ======== Epoch 158 =======
# Loss => train:0.87028, valid:0.94277, Elapsed time => 0.208 sec
# =======================================
#
# ======== Epoch 159 =======
# Loss => train:0.87228, valid:0.93637, Elapsed time => 0.209 sec
# =======================================
#
# ======== Epoch 160 =======
# Loss => train:0.88352, valid:1.00241, Elapsed time => 0.203 sec
# =======================================
#
# ======== Epoch 161 =======
# Loss => train:0.87739, valid:0.95115, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 162 =======
# Loss => train:0.88449, valid:0.96164, Elapsed time => 0.203 sec
# =======================================
#
# ======== Epoch 163 =======
# Loss => train:0.88487, valid:0.94345, Elapsed time => 0.218 sec
# =======================================
#
# ======== Epoch 164 =======
# Loss => train:0.87008, valid:0.93421, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 165 =======
# Loss => train:0.86738, valid:0.93863, Elapsed time => 0.203 sec
# =======================================
#
# ======== Epoch 166 =======
# Loss => train:0.87212, valid:0.93580, Elapsed time => 0.221 sec
# =======================================
#
# ======== Epoch 167 =======
# Loss => train:0.87287, valid:0.96672, Elapsed time => 0.202 sec
# =======================================
#
# ======== Epoch 168 =======
# Loss => train:0.88404, valid:0.94218, Elapsed time => 0.199 sec
# =======================================
#
# ======== Epoch 169 =======
# Loss => train:0.87482, valid:1.02904, Elapsed time => 0.211 sec
# =======================================
#
# ======== Epoch 170 =======
# Loss => train:0.87708, valid:0.93299, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 171 =======
# Loss => train:0.89622, valid:0.98497, Elapsed time => 0.213 sec
# =======================================
#
# ======== Epoch 172 =======
# Loss => train:0.89063, valid:0.96147, Elapsed time => 0.228 sec
# =======================================
#
# ======== Epoch 173 =======
# Loss => train:0.87961, valid:0.93469, Elapsed time => 0.218 sec
# =======================================
#
# ======== Epoch 174 =======
# Loss => train:0.86857, valid:0.93252, Elapsed time => 0.241 sec
# =======================================
#
# ======== Epoch 175 =======
# Loss => train:0.86981, valid:0.93802, Elapsed time => 0.227 sec
# =======================================
#
# ======== Epoch 176 =======
# Loss => train:0.87513, valid:0.99208, Elapsed time => 0.216 sec
# =======================================
#
# ======== Epoch 177 =======
# Loss => train:0.87768, valid:0.95549, Elapsed time => 0.216 sec
# =======================================
#
# ======== Epoch 178 =======
# Loss => train:0.88466, valid:0.94073, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 179 =======
# Loss => train:0.87264, valid:0.97632, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 180 =======
# Loss => train:0.87421, valid:0.94684, Elapsed time => 0.218 sec
# =======================================
#
# ======== Epoch 181 =======
# Loss => train:0.86911, valid:0.93954, Elapsed time => 0.204 sec
# =======================================
#
# ======== Epoch 182 =======
# Loss => train:0.87507, valid:0.93800, Elapsed time => 0.196 sec
# =======================================
#
# ======== Epoch 183 =======
# Loss => train:0.88122, valid:0.99881, Elapsed time => 0.193 sec
# =======================================
#
# ======== Epoch 184 =======
# Loss => train:0.87186, valid:0.98194, Elapsed time => 0.202 sec
# =======================================
#
# ======== Epoch 185 =======
# Loss => train:0.87063, valid:0.93210, Elapsed time => 0.219 sec
# =======================================
#
# ======== Epoch 186 =======
# Loss => train:0.86843, valid:1.01950, Elapsed time => 0.209 sec
# =======================================
#
# ======== Epoch 187 =======
# Loss => train:0.87235, valid:0.94155, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 188 =======
# Loss => train:0.86351, valid:1.04601, Elapsed time => 0.219 sec
# =======================================
#
# ======== Epoch 189 =======
# Loss => train:0.87662, valid:0.94656, Elapsed time => 0.212 sec
# =======================================
#
# ======== Epoch 190 =======
# Loss => train:0.86028, valid:0.93821, Elapsed time => 0.202 sec
# =======================================
#
# ======== Epoch 191 =======
# Loss => train:0.87643, valid:0.94218, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 192 =======
# Loss => train:0.86663, valid:0.94408, Elapsed time => 0.196 sec
# =======================================
#
# ======== Epoch 193 =======
# Loss => train:0.85916, valid:0.95069, Elapsed time => 0.199 sec
# =======================================
#
# ======== Epoch 194 =======
# Loss => train:0.90034, valid:0.98959, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 195 =======
# Loss => train:0.90583, valid:0.93662, Elapsed time => 0.212 sec
# =======================================
#
# ======== Epoch 196 =======
# Loss => train:0.88098, valid:0.97952, Elapsed time => 0.216 sec
# =======================================
#
# ======== Epoch 197 =======
# Loss => train:0.87311, valid:0.95094, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 198 =======
# Loss => train:0.88213, valid:0.95501, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 199 =======
# Loss => train:0.87185, valid:0.93334, Elapsed time => 0.213 sec
# =======================================
#
# ======== Epoch 200 =======
# Loss => train:0.86330, valid:0.95879, Elapsed time => 0.208 sec
# =======================================
#
# ======== Epoch 201 =======
# Loss => train:0.86114, valid:0.94396, Elapsed time => 0.212 sec
# =======================================
#
# ======== Epoch 202 =======
# Loss => train:0.86223, valid:0.93530, Elapsed time => 0.200 sec
# =======================================
#
# ======== Epoch 203 =======
# Loss => train:0.85775, valid:0.97064, Elapsed time => 0.201 sec
# =======================================
#
# ======== Epoch 204 =======
# Loss => train:0.86207, valid:0.98493, Elapsed time => 0.195 sec
# =======================================
#
# ======== Epoch 205 =======
# Loss => train:0.86286, valid:0.93313, Elapsed time => 0.198 sec
# =======================================
#
# ======== Epoch 206 =======
# Loss => train:0.89068, valid:0.94928, Elapsed time => 0.195 sec
# =======================================
#
# ======== Epoch 207 =======
# Loss => train:0.86330, valid:0.93747, Elapsed time => 0.191 sec
# =======================================
#
# ======== Epoch 208 =======
# Loss => train:0.88055, valid:0.96587, Elapsed time => 0.196 sec
# =======================================
#
# ======== Epoch 209 =======
# Loss => train:0.86398, valid:0.95213, Elapsed time => 0.192 sec
# =======================================
#
# ======== Epoch 210 =======
# Loss => train:0.85587, valid:0.93610, Elapsed time => 0.197 sec
# =======================================
#
# ======== Epoch 211 =======
# Loss => train:0.87280, valid:0.93686, Elapsed time => 0.199 sec
# =======================================
#
# ======== Epoch 212 =======
# Loss => train:0.85627, valid:0.93168, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 213 =======
# Loss => train:0.86532, valid:0.99263, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 214 =======
# Loss => train:0.86002, valid:0.93107, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 215 =======
# Loss => train:0.86365, valid:0.93065, Elapsed time => 0.218 sec
# =======================================
#
# ======== Epoch 216 =======
# Loss => train:0.86288, valid:0.94503, Elapsed time => 0.197 sec
# =======================================
#
# ======== Epoch 217 =======
# Loss => train:0.85293, valid:0.97996, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 218 =======
# Loss => train:0.85693, valid:0.95701, Elapsed time => 0.224 sec
# =======================================
#
# ======== Epoch 219 =======
# Loss => train:0.87593, valid:0.94659, Elapsed time => 0.224 sec
# =======================================
#
# ======== Epoch 220 =======
# Loss => train:0.87929, valid:0.93240, Elapsed time => 0.225 sec
# =======================================
#
# ======== Epoch 221 =======
# Loss => train:0.86287, valid:0.95018, Elapsed time => 0.221 sec
# =======================================
#
# ======== Epoch 222 =======
# Loss => train:0.85756, valid:0.93265, Elapsed time => 0.213 sec
# =======================================
#
# ======== Epoch 223 =======
# Loss => train:0.87699, valid:0.95549, Elapsed time => 0.219 sec
# =======================================
#
# ======== Epoch 224 =======
# Loss => train:0.87585, valid:0.94672, Elapsed time => 0.219 sec
# =======================================
#
# ======== Epoch 225 =======
# Loss => train:0.86648, valid:0.93273, Elapsed time => 0.226 sec
# =======================================
#
# ======== Epoch 226 =======
# Loss => train:0.88050, valid:0.93670, Elapsed time => 0.216 sec
# =======================================
#
# ======== Epoch 227 =======
# Loss => train:0.87918, valid:0.93405, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 228 =======
# Loss => train:0.85369, valid:0.96297, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 229 =======
# Loss => train:0.85795, valid:0.93521, Elapsed time => 0.204 sec
# =======================================
#
# ======== Epoch 230 =======
# Loss => train:0.85845, valid:0.94056, Elapsed time => 0.216 sec
# =======================================
#
# ======== Epoch 231 =======
# Loss => train:0.85373, valid:0.96522, Elapsed time => 0.212 sec
# =======================================
#
# ======== Epoch 232 =======
# Loss => train:0.85305, valid:0.93921, Elapsed time => 0.201 sec
# =======================================
#
# ======== Epoch 233 =======
# Loss => train:0.85980, valid:0.98014, Elapsed time => 0.201 sec
# =======================================
#
# ======== Epoch 234 =======
# Loss => train:0.88508, valid:1.00962, Elapsed time => 0.211 sec
# =======================================
#
# ======== Epoch 235 =======
# Loss => train:0.87686, valid:0.94212, Elapsed time => 0.204 sec
# =======================================
#
# ======== Epoch 236 =======
# Loss => train:0.87448, valid:0.98279, Elapsed time => 0.198 sec
# =======================================
#
# ======== Epoch 237 =======
# Loss => train:0.85156, valid:0.93568, Elapsed time => 0.201 sec
# =======================================
#
# ======== Epoch 238 =======
# Loss => train:0.86039, valid:0.96376, Elapsed time => 0.211 sec
# =======================================
#
# ======== Epoch 239 =======
# Loss => train:0.85594, valid:0.93420, Elapsed time => 0.228 sec
# =======================================
#
# ======== Epoch 240 =======
# Loss => train:0.84891, valid:0.94405, Elapsed time => 0.205 sec
# =======================================
#
# ======== Epoch 241 =======
# Loss => train:0.85085, valid:0.92971, Elapsed time => 0.207 sec
# =======================================
#
# ======== Epoch 242 =======
# Loss => train:0.85290, valid:0.95398, Elapsed time => 0.212 sec
# =======================================
#
# ======== Epoch 243 =======
# Loss => train:0.85273, valid:0.94710, Elapsed time => 0.207 sec
# =======================================
#
# ======== Epoch 244 =======
# Loss => train:0.84733, valid:0.95624, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 245 =======
# Loss => train:0.86505, valid:0.92873, Elapsed time => 0.208 sec
# =======================================
#
# ======== Epoch 246 =======
# Loss => train:0.84682, valid:0.93085, Elapsed time => 0.209 sec
# =======================================
#
# ======== Epoch 247 =======
# Loss => train:0.85121, valid:0.93790, Elapsed time => 0.211 sec
# =======================================
#
# ======== Epoch 248 =======
# Loss => train:0.84804, valid:0.98783, Elapsed time => 0.207 sec
# =======================================
#
# ======== Epoch 249 =======
# Loss => train:0.86350, valid:1.01476, Elapsed time => 0.211 sec
# =======================================
#
# ======== Epoch 250 =======
# Loss => train:0.85424, valid:0.94192, Elapsed time => 0.194 sec
# =======================================
#
# ======== Epoch 251 =======
# Loss => train:0.88969, valid:0.96057, Elapsed time => 0.202 sec
# =======================================
#
# ======== Epoch 252 =======
# Loss => train:0.85703, valid:0.93506, Elapsed time => 0.195 sec
# =======================================
#
# ======== Epoch 253 =======
# Loss => train:0.85381, valid:0.96942, Elapsed time => 0.202 sec
# =======================================
#
# ======== Epoch 254 =======
# Loss => train:0.86033, valid:0.94745, Elapsed time => 0.194 sec
# =======================================
#
# ======== Epoch 255 =======
# Loss => train:0.86179, valid:0.97048, Elapsed time => 0.194 sec
# =======================================
#
# ======== Epoch 256 =======
# Loss => train:0.85102, valid:0.97794, Elapsed time => 0.192 sec
# =======================================
#
# ======== Epoch 257 =======
# Loss => train:0.85254, valid:0.95516, Elapsed time => 0.195 sec
# =======================================
#
# ======== Epoch 258 =======
# Loss => train:0.85873, valid:1.00475, Elapsed time => 0.189 sec
# =======================================
#
# ======== Epoch 259 =======
# Loss => train:0.86100, valid:0.93270, Elapsed time => 0.199 sec
# =======================================
#
# ======== Epoch 260 =======
# Loss => train:0.84798, valid:0.93928, Elapsed time => 0.189 sec
# =======================================
#
# ======== Epoch 261 =======
# Loss => train:0.84513, valid:0.93899, Elapsed time => 0.195 sec
# =======================================
#
# ======== Epoch 262 =======
# Loss => train:0.84720, valid:0.94463, Elapsed time => 0.195 sec
# =======================================
#
# ======== Epoch 263 =======
# Loss => train:0.85071, valid:0.94234, Elapsed time => 0.198 sec
# =======================================
#
# ======== Epoch 264 =======
# Loss => train:0.84387, valid:0.92869, Elapsed time => 0.196 sec
# =======================================
#
# ======== Epoch 265 =======
# Loss => train:0.84374, valid:0.94454, Elapsed time => 0.221 sec
# =======================================
#
# ======== Epoch 266 =======
# Loss => train:0.84755, valid:0.94633, Elapsed time => 0.214 sec
# =======================================
#
# ======== Epoch 267 =======
# Loss => train:0.85206, valid:1.03526, Elapsed time => 0.216 sec
# =======================================
#
# ======== Epoch 268 =======
# Loss => train:0.84992, valid:0.96497, Elapsed time => 0.225 sec
# =======================================
#
# ======== Epoch 269 =======
# Loss => train:0.85491, valid:0.96982, Elapsed time => 0.213 sec
# =======================================
#
# ======== Epoch 270 =======
# Loss => train:0.85800, valid:0.94691, Elapsed time => 0.209 sec
# =======================================
#
# ======== Epoch 271 =======
# Loss => train:0.85045, valid:0.93939, Elapsed time => 0.213 sec
# =======================================
#
# ======== Epoch 272 =======
# Loss => train:0.85473, valid:0.93777, Elapsed time => 0.202 sec
# =======================================
#
# ======== Epoch 273 =======
# Loss => train:0.85664, valid:0.93613, Elapsed time => 0.202 sec
# =======================================
#
# ======== Epoch 274 =======
# Loss => train:0.85186, valid:0.94726, Elapsed time => 0.198 sec
# =======================================
#
# ======== Epoch 275 =======
# Loss => train:0.87694, valid:0.92994, Elapsed time => 0.199 sec
# =======================================
#
# ======== Epoch 276 =======
# Loss => train:0.86268, valid:0.98183, Elapsed time => 0.195 sec
# =======================================
#
# ======== Epoch 277 =======
# Loss => train:0.85172, valid:0.94585, Elapsed time => 0.200 sec
# =======================================
#
# ======== Epoch 278 =======
# Loss => train:0.84293, valid:0.94909, Elapsed time => 0.194 sec
# =======================================
#
# ======== Epoch 279 =======
# Loss => train:0.85813, valid:0.93291, Elapsed time => 0.216 sec
# =======================================
#
# ======== Epoch 280 =======
# Loss => train:0.84723, valid:0.93342, Elapsed time => 0.193 sec
# =======================================
#
# ======== Epoch 281 =======
# Loss => train:0.83715, valid:0.93650, Elapsed time => 0.201 sec
# =======================================
#
# ======== Epoch 282 =======
# Loss => train:0.84779, valid:0.93291, Elapsed time => 0.199 sec
# =======================================
#
# ======== Epoch 283 =======
# Loss => train:0.84356, valid:0.92772, Elapsed time => 0.203 sec
# =======================================
#
# ======== Epoch 284 =======
# Loss => train:0.86822, valid:0.94763, Elapsed time => 0.193 sec
# =======================================
#
# ======== Epoch 285 =======
# Loss => train:0.84764, valid:0.93621, Elapsed time => 0.195 sec
# =======================================
#
# ======== Epoch 286 =======
# Loss => train:0.84631, valid:0.93352, Elapsed time => 0.191 sec
# =======================================
#
# ======== Epoch 287 =======
# Loss => train:0.84807, valid:0.93216, Elapsed time => 0.193 sec
# =======================================
#
# ======== Epoch 288 =======
# Loss => train:0.84665, valid:0.92964, Elapsed time => 0.190 sec
# =======================================
#
# ======== Epoch 289 =======
# Loss => train:0.84167, valid:0.93102, Elapsed time => 0.206 sec
# =======================================
#
# ======== Epoch 290 =======
# Loss => train:0.85450, valid:0.93320, Elapsed time => 0.202 sec
# =======================================
#
# ======== Epoch 291 =======
# Loss => train:0.84566, valid:0.93213, Elapsed time => 0.215 sec
# =======================================
#
# ======== Epoch 292 =======
# Loss => train:0.85687, valid:0.93421, Elapsed time => 0.222 sec
# =======================================
#
# ======== Epoch 293 =======
# Loss => train:0.83835, valid:0.93834, Elapsed time => 0.208 sec
# =======================================
#
# ======== Epoch 294 =======
# Loss => train:0.84528, valid:0.93316, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 295 =======
# Loss => train:0.84263, valid:0.94356, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 296 =======
# Loss => train:0.84715, valid:1.03859, Elapsed time => 0.210 sec
# =======================================
#
# ======== Epoch 297 =======
# Loss => train:0.84580, valid:0.93952, Elapsed time => 0.200 sec
# =======================================
#
# ======== Epoch 298 =======
# Loss => train:0.84113, valid:0.94159, Elapsed time => 0.197 sec
# =======================================
#
# ======== Epoch 299 =======
# Loss => train:0.84265, valid:0.96878, Elapsed time => 0.201 sec
# =======================================
#
# ======== Epoch 300 =======
# Loss => train:0.85083, valid:0.94984, Elapsed time => 0.193 sec
# =======================================
#
# ======== Epoch 301 =======
# Loss => train:0.85175, valid:0.95613, Elapsed time => 0.197 sec
# =======================================
#
# ======== Epoch 302 =======
# Loss => train:0.83862, valid:0.94726, Elapsed time => 0.198 sec
# =======================================
#
# ======== Epoch 303 =======
# Loss => train:0.83597, valid:0.93753, Elapsed time => 0.196 sec
# =======================================
#
# ======== Epoch 304 =======
# Loss => train:0.83776, valid:0.94505, Elapsed time => 0.192 sec
# =======================================
#
# ======== Epoch 305 =======
# Loss => train:0.86927, valid:0.95480, Elapsed time => 0.196 sec
# =======================================
#
# ======== Epoch 306 =======
# Loss => train:0.85211, valid:0.95194, Elapsed time => 0.189 sec
# =======================================
#
# ======== Epoch 307 =======
# Loss => train:0.83740, valid:0.97890, Elapsed time => 0.195 sec
# =======================================
#
# ======== Epoch 308 =======
# Loss => train:0.83810, valid:0.93018, Elapsed time => 0.189 sec
# =======================================
#
# ======== Epoch 309 =======
# Loss => train:0.84312, valid:0.93154, Elapsed time => 0.193 sec
# =======================================
#
# ======== Epoch 310 =======
# Loss => train:0.83895, valid:0.93430, Elapsed time => 0.190 sec
# =======================================
#
# ======== Epoch 311 =======
# Loss => train:0.83544, valid:0.93363, Elapsed time => 0.192 sec
# =======================================
#
# ======== Epoch 312 =======
# Loss => train:0.84006, valid:0.93835, Elapsed time => 0.195 sec
# =======================================
#
# ======== Epoch 313 =======
# Loss => train:0.84129, valid:0.95324, Elapsed time => 0.215 sec
# =======================================

# %% [markdown]
# # Learning Curve

# %%
import matplotlib.pyplot as plt 

plt.plot(train_loss_history)
plt.plot(valid_loss_history)
plt.axhline(y=min(valid_loss_history), color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# # Load best model

# %%
checkpoint = torch.load('./saved_model.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']

print(epoch, loss.item())
# Out:
# 283 0.927715539932251

# %% [markdown]
# # Evaluation

# %%
prediction = model(X_test)
loss = criterion(prediction[:,0], y_test)

print(f"loss: {loss:.5f}")
# Out:
# loss: 1.56922

# %%
plt.figure(figsize=(15,6))
plt.plot(df_test.iloc[5:]['date'], y_test.detach().numpy())
plt.plot(df_test.iloc[5:]['date'], prediction[:,0].detach().numpy())
plt.show()
