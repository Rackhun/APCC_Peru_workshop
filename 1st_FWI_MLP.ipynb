# %%
import torch
import torchvision

import pandas as pd
import numpy as np

# %% [markdown]
# # Seed

# %%
seed_number = 44

torch.manual_seed(seed_number)
torch.cuda.manual_seed(seed_number)
torch.cuda.manual_seed_all(seed_number) # if use multi-GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed_number)

# %% [markdown]
# # Data Load

# %%
#df = pd.read_csv('./data/fwi_peru.csv')
df = pd.read_csv('https://raw.githubusercontent.com/Rackhun/AI-programming-course/refs/heads/main/data/fwi_peru.csv')

print(df.shape)
df.head()
# Out:
# (7670, 8)
#          date       fwi    fbupinx    drtcode   dufmcode    ffmcode    fdsrte  \
# 0  2003-01-01  3.032478  43.350230  303.92447  28.816147  59.494816  0.821229
# 1  2003-01-02  3.234723  43.817448  306.08072  29.067446  58.859665  0.910691
# 2  2003-01-03  3.840679  44.936455  309.48050  29.878538  64.760050  1.050648
# 3  2003-01-04  4.291818  45.781628  312.24307  30.441364  65.765340  1.283834
# 4  2003-01-05  4.434349  46.758377  315.64978  31.114819  65.916730  1.326426
#
#     infsinx
# 0  1.228552
# 1  1.194067
# 2  1.604336
# 3  1.759281
# 4  1.818198

# %%
df.tail()
# Out:
#             date       fwi    fbupinx    drtcode   dufmcode    ffmcode  \
# 7665  2023-12-27  2.525733  36.758522  257.50085  24.618862  35.218212
# 7666  2023-12-28  1.647023  30.309649  242.49062  19.879116  40.500847
# 7667  2023-12-29  1.403245  26.050838  236.74654  16.661034  49.327080
# 7668  2023-12-30  1.826561  25.967650  236.96635  16.680098  53.704983
# 7669  2023-12-31  1.933431  24.840988  231.64226  15.873484  38.895653
#
#         fdsrte   infsinx
# 7665  0.861941  0.750828
# 7666  0.516756  0.528351
# 7667  0.337519  0.615339
# 7668  0.466286  0.831606
# 7669  0.583733  0.600974

# %%
df.dtypes
# Out:
# date         object
# fwi         float64
# fbupinx     float64
# drtcode     float64
# dufmcode    float64
# ffmcode     float64
# fdsrte      float64
# infsinx     float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# date        datetime64[ns]
# fwi                float64
# fbupinx            float64
# drtcode            float64
# dufmcode           float64
# ffmcode            float64
# fdsrte             float64
# infsinx            float64
# dtype: object

# %%
df_train = df[df['date'].dt.year < 2019].reset_index(drop=True)
df_test  = df[df['date'].dt.year >= 2019].reset_index(drop=True)

print(df_train.shape)
print(df_test.shape)
# Out:
# (5844, 8)
# (1826, 8)

# %%
X = df_train.loc[:5842,['fwi', 'fbupinx', 'drtcode', 'dufmcode', 'ffmcode', 'fdsrte', 'infsinx']].values
y = df_train.loc[1:,'fwi'].values

X_test = df_test.loc[:1824, ['fwi', 'fbupinx', 'drtcode', 'dufmcode', 'ffmcode', 'fdsrte', 'infsinx']].values
y_test = df_test.loc[1:, 'fwi'].values

print(X.shape, y.shape)
print(X_test.shape, y_test.shape)
# Out:
# (5843, 7) (5843,)
# (1825, 7) (1825,)

# %% [markdown]
# # Normalization

# %%
X_max = np.max(X, axis=0)
X_min = np.min(X, axis=0)

X      = (X      - X_min) / (X_max - X_min + 1e-10)
X_test = (X_test - X_min) / (X_max - X_min + 1e-10)

# %%
print(np.max(X), np.min(X))
print(np.max(X_test), np.min(X_test))
# Out:
# 0.9999999999997156 0.0
# 1.1532220684416759 0.00043293813048260325

# %% [markdown]
# # Split data

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=seed_number)

print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
# Out:
# (4674, 7) (4674,)
# (1169, 7) (1169,)

# %% [markdown]
# # Data loader

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

X_train = torch.FloatTensor(X_train).to(device=device)
X_valid = torch.FloatTensor(X_valid).to(device=device)
X_test  = torch.FloatTensor(X_test).to(device=device)

y_train = torch.FloatTensor(y_train).to(device=device)
y_valid = torch.FloatTensor(y_valid).to(device=device)
y_test  = torch.FloatTensor(y_test).to(device=device)
# Out:
# cpu

# %%
train_ds = torch.utils.data.TensorDataset(X_train, y_train)
valid_ds = torch.utils.data.TensorDataset(X_valid, y_valid)

train_loader = torch.utils.data.DataLoader(train_ds, batch_size=128, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_ds, batch_size=128, shuffle=False)

# %% [markdown]
# # Model (MLP)

# %%
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.fully_connected_layer_1 = torch.nn.Linear(7, 32)
        self.fully_connected_layer_2 = torch.nn.Linear(32,32)
        self.fully_connected_layer_3 = torch.nn.Linear(32,32)
        self.fully_connected_layer_4 = torch.nn.Linear(32, 1)
        
    def forward(self, xb):        
        out = self.fully_connected_layer_1(xb)
        out = torch.nn.ReLU()(out)
        
        out = self.fully_connected_layer_2(out)
        out = torch.nn.ReLU()(out)
        
        out = self.fully_connected_layer_3(out)
        out = torch.nn.ReLU()(out)
        
        out = self.fully_connected_layer_4(out)
        return out

# %%
model = Net().to(device)
print(model)
# Out:
# Net(
#   (fully_connected_layer_1): Linear(in_features=7, out_features=32, bias=True)
#   (fully_connected_layer_2): Linear(in_features=32, out_features=32, bias=True)
#   (fully_connected_layer_3): Linear(in_features=32, out_features=32, bias=True)
#   (fully_connected_layer_4): Linear(in_features=32, out_features=1, bias=True)
# )

# %% [markdown]
# # Cost function

# %%
criterion = torch.nn.MSELoss()

# %% [markdown]
# # Optimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # Training

# %%
import time 

is_train = True
epoch, early_stopping = 0, 0
train_loss_history, valid_loss_history = [], []

while is_train:
    start = time.time()
    train_loss, train_count = 0., 0.
    epoch += 1
    early_stopping += 1
    
    for xb, yb in train_loader:
        prediction = model(xb)
        loss = criterion(prediction[:,0], yb)
        train_loss += loss.item()*len(yb)
        train_count += len(yb)
        
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    with torch.no_grad():
        valid_loss = 0
        valid_count = 0.
        
        for xb, yb in valid_loader:
            prediction = model(xb)
            valid_loss += criterion(prediction[:,0], yb)*len(yb)
            valid_count += len(yb)
        
    train_loss /= train_count
    valid_loss /= valid_count    
    
    train_loss_history.append(train_loss)
    valid_loss_history.append(valid_loss)
    
    if min(valid_loss_history) == valid_loss:
        early_stopping = 0
        
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': valid_loss,
        }, './saved_model.pt')
        
    if early_stopping == 30:
        is_train = False
            
    print(f"======== Epoch {epoch} =======")
    print(f"Loss => train:{train_loss:.5f}, valid:{valid_loss:.5f}, Elapsed time => {time.time()-start:.3f} sec")
    print("=======================================\n")
# Out:
# ======== Epoch 1 =======
# Loss => train:32.87655, valid:30.05143, Elapsed time => 0.218 sec
# =======================================
#
# ======== Epoch 2 =======
# Loss => train:17.50844, valid:4.93517, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 3 =======
# Loss => train:3.36549, valid:3.19309, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 4 =======
# Loss => train:2.44512, valid:2.29064, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 5 =======
# Loss => train:1.75809, valid:1.60535, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 6 =======
# Loss => train:1.21264, valid:1.08312, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 7 =======
# Loss => train:0.83257, valid:0.75992, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 8 =======
# Loss => train:0.63065, valid:0.59239, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 9 =======
# Loss => train:0.54095, valid:0.52197, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 10 =======
# Loss => train:0.50184, valid:0.49302, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 11 =======
# Loss => train:0.48379, valid:0.47420, Elapsed time => 0.143 sec
# =======================================
#
# ======== Epoch 12 =======
# Loss => train:0.47432, valid:0.46158, Elapsed time => 0.131 sec
# =======================================
#
# ======== Epoch 13 =======
# Loss => train:0.46834, valid:0.45828, Elapsed time => 0.148 sec
# =======================================
#
# ======== Epoch 14 =======
# Loss => train:0.46829, valid:0.45211, Elapsed time => 0.132 sec
# =======================================
#
# ======== Epoch 15 =======
# Loss => train:0.46081, valid:0.44585, Elapsed time => 0.132 sec
# =======================================
#
# ======== Epoch 16 =======
# Loss => train:0.46283, valid:0.46041, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 17 =======
# Loss => train:0.45784, valid:0.44371, Elapsed time => 0.136 sec
# =======================================
#
# ======== Epoch 18 =======
# Loss => train:0.45499, valid:0.44366, Elapsed time => 0.137 sec
# =======================================
#
# ======== Epoch 19 =======
# Loss => train:0.45463, valid:0.43946, Elapsed time => 0.147 sec
# =======================================
#
# ======== Epoch 20 =======
# Loss => train:0.45065, valid:0.44017, Elapsed time => 0.134 sec
# =======================================
#
# ======== Epoch 21 =======
# Loss => train:0.45112, valid:0.43502, Elapsed time => 0.136 sec
# =======================================
#
# ======== Epoch 22 =======
# Loss => train:0.44847, valid:0.43558, Elapsed time => 0.130 sec
# =======================================
#
# ======== Epoch 23 =======
# Loss => train:0.45043, valid:0.43246, Elapsed time => 0.133 sec
# =======================================
#
# ======== Epoch 24 =======
# Loss => train:0.44554, valid:0.43214, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 25 =======
# Loss => train:0.44319, valid:0.43301, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 26 =======
# Loss => train:0.44322, valid:0.43109, Elapsed time => 0.119 sec
# =======================================
#
# ======== Epoch 27 =======
# Loss => train:0.43885, valid:0.43248, Elapsed time => 0.119 sec
# =======================================
#
# ======== Epoch 28 =======
# Loss => train:0.43820, valid:0.43092, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 29 =======
# Loss => train:0.43793, valid:0.42873, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 30 =======
# Loss => train:0.44157, valid:0.42698, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 31 =======
# Loss => train:0.43734, valid:0.42709, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 32 =======
# Loss => train:0.43560, valid:0.42984, Elapsed time => 0.117 sec
# =======================================
#
# ======== Epoch 33 =======
# Loss => train:0.43616, valid:0.43257, Elapsed time => 0.117 sec
# =======================================
#
# ======== Epoch 34 =======
# Loss => train:0.44066, valid:0.43199, Elapsed time => 0.128 sec
# =======================================
#
# ======== Epoch 35 =======
# Loss => train:0.43750, valid:0.42381, Elapsed time => 0.135 sec
# =======================================
#
# ======== Epoch 36 =======
# Loss => train:0.43305, valid:0.44386, Elapsed time => 0.130 sec
# =======================================
#
# ======== Epoch 37 =======
# Loss => train:0.43111, valid:0.42413, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 38 =======
# Loss => train:0.43353, valid:0.42098, Elapsed time => 0.122 sec
# =======================================
#
# ======== Epoch 39 =======
# Loss => train:0.42996, valid:0.43360, Elapsed time => 0.128 sec
# =======================================
#
# ======== Epoch 40 =======
# Loss => train:0.42984, valid:0.42097, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 41 =======
# Loss => train:0.43004, valid:0.41971, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 42 =======
# Loss => train:0.42840, valid:0.42045, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 43 =======
# Loss => train:0.42961, valid:0.41871, Elapsed time => 0.127 sec
# =======================================
#
# ======== Epoch 44 =======
# Loss => train:0.42830, valid:0.44097, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 45 =======
# Loss => train:0.42552, valid:0.42612, Elapsed time => 0.134 sec
# =======================================
#
# ======== Epoch 46 =======
# Loss => train:0.42451, valid:0.41914, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 47 =======
# Loss => train:0.42579, valid:0.42055, Elapsed time => 0.119 sec
# =======================================
#
# ======== Epoch 48 =======
# Loss => train:0.42523, valid:0.42395, Elapsed time => 0.115 sec
# =======================================
#
# ======== Epoch 49 =======
# Loss => train:0.42501, valid:0.44088, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 50 =======
# Loss => train:0.42911, valid:0.44712, Elapsed time => 0.127 sec
# =======================================
#
# ======== Epoch 51 =======
# Loss => train:0.42193, valid:0.41557, Elapsed time => 0.145 sec
# =======================================
#
# ======== Epoch 52 =======
# Loss => train:0.42542, valid:0.41507, Elapsed time => 0.130 sec
# =======================================
#
# ======== Epoch 53 =======
# Loss => train:0.42614, valid:0.41867, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 54 =======
# Loss => train:0.41940, valid:0.41549, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 55 =======
# Loss => train:0.42254, valid:0.41140, Elapsed time => 0.134 sec
# =======================================
#
# ======== Epoch 56 =======
# Loss => train:0.42123, valid:0.41075, Elapsed time => 0.134 sec
# =======================================
#
# ======== Epoch 57 =======
# Loss => train:0.42006, valid:0.40954, Elapsed time => 0.131 sec
# =======================================
#
# ======== Epoch 58 =======
# Loss => train:0.42015, valid:0.41893, Elapsed time => 0.127 sec
# =======================================
#
# ======== Epoch 59 =======
# Loss => train:0.43275, valid:0.46107, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 60 =======
# Loss => train:0.42365, valid:0.40909, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 61 =======
# Loss => train:0.42229, valid:0.41020, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 62 =======
# Loss => train:0.41515, valid:0.40949, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 63 =======
# Loss => train:0.41606, valid:0.40933, Elapsed time => 0.117 sec
# =======================================
#
# ======== Epoch 64 =======
# Loss => train:0.41374, valid:0.41091, Elapsed time => 0.117 sec
# =======================================
#
# ======== Epoch 65 =======
# Loss => train:0.41413, valid:0.40633, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 66 =======
# Loss => train:0.41281, valid:0.41200, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 67 =======
# Loss => train:0.41323, valid:0.40897, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 68 =======
# Loss => train:0.41629, valid:0.42761, Elapsed time => 0.119 sec
# =======================================
#
# ======== Epoch 69 =======
# Loss => train:0.41135, valid:0.40638, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 70 =======
# Loss => train:0.41239, valid:0.40963, Elapsed time => 0.122 sec
# =======================================
#
# ======== Epoch 71 =======
# Loss => train:0.41680, valid:0.40308, Elapsed time => 0.135 sec
# =======================================
#
# ======== Epoch 72 =======
# Loss => train:0.41083, valid:0.41847, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 73 =======
# Loss => train:0.41622, valid:0.40052, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 74 =======
# Loss => train:0.40810, valid:0.41466, Elapsed time => 0.117 sec
# =======================================
#
# ======== Epoch 75 =======
# Loss => train:0.41069, valid:0.40573, Elapsed time => 0.118 sec
# =======================================
#
# ======== Epoch 76 =======
# Loss => train:0.41273, valid:0.41199, Elapsed time => 0.119 sec
# =======================================
#
# ======== Epoch 77 =======
# Loss => train:0.41067, valid:0.40573, Elapsed time => 0.117 sec
# =======================================
#
# ======== Epoch 78 =======
# Loss => train:0.41519, valid:0.40323, Elapsed time => 0.116 sec
# =======================================
#
# ======== Epoch 79 =======
# Loss => train:0.40813, valid:0.39813, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 80 =======
# Loss => train:0.40787, valid:0.39968, Elapsed time => 0.118 sec
# =======================================
#
# ======== Epoch 81 =======
# Loss => train:0.40854, valid:0.40355, Elapsed time => 0.115 sec
# =======================================
#
# ======== Epoch 82 =======
# Loss => train:0.40874, valid:0.39931, Elapsed time => 0.118 sec
# =======================================
#
# ======== Epoch 83 =======
# Loss => train:0.40586, valid:0.39650, Elapsed time => 0.127 sec
# =======================================
#
# ======== Epoch 84 =======
# Loss => train:0.40305, valid:0.40048, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 85 =======
# Loss => train:0.40512, valid:0.41117, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 86 =======
# Loss => train:0.40178, valid:0.40837, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 87 =======
# Loss => train:0.40384, valid:0.41406, Elapsed time => 0.117 sec
# =======================================
#
# ======== Epoch 88 =======
# Loss => train:0.40339, valid:0.39290, Elapsed time => 0.131 sec
# =======================================
#
# ======== Epoch 89 =======
# Loss => train:0.40933, valid:0.42075, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 90 =======
# Loss => train:0.40639, valid:0.39385, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 91 =======
# Loss => train:0.39891, valid:0.42381, Elapsed time => 0.135 sec
# =======================================
#
# ======== Epoch 92 =======
# Loss => train:0.40025, valid:0.39061, Elapsed time => 0.131 sec
# =======================================
#
# ======== Epoch 93 =======
# Loss => train:0.39968, valid:0.39990, Elapsed time => 0.133 sec
# =======================================
#
# ======== Epoch 94 =======
# Loss => train:0.39785, valid:0.39333, Elapsed time => 0.127 sec
# =======================================
#
# ======== Epoch 95 =======
# Loss => train:0.39913, valid:0.39883, Elapsed time => 0.135 sec
# =======================================
#
# ======== Epoch 96 =======
# Loss => train:0.40133, valid:0.39395, Elapsed time => 0.130 sec
# =======================================
#
# ======== Epoch 97 =======
# Loss => train:0.40092, valid:0.39103, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 98 =======
# Loss => train:0.40494, valid:0.38766, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 99 =======
# Loss => train:0.39851, valid:0.39301, Elapsed time => 0.130 sec
# =======================================
#
# ======== Epoch 100 =======
# Loss => train:0.39737, valid:0.38783, Elapsed time => 0.133 sec
# =======================================
#
# ======== Epoch 101 =======
# Loss => train:0.39952, valid:0.40861, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 102 =======
# Loss => train:0.39820, valid:0.38785, Elapsed time => 0.117 sec
# =======================================
#
# ======== Epoch 103 =======
# Loss => train:0.39690, valid:0.38718, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 104 =======
# Loss => train:0.39571, valid:0.38733, Elapsed time => 0.119 sec
# =======================================
#
# ======== Epoch 105 =======
# Loss => train:0.39136, valid:0.38554, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 106 =======
# Loss => train:0.39827, valid:0.38594, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 107 =======
# Loss => train:0.39186, valid:0.38634, Elapsed time => 0.127 sec
# =======================================
#
# ======== Epoch 108 =======
# Loss => train:0.39642, valid:0.39045, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 109 =======
# Loss => train:0.39341, valid:0.38416, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 110 =======
# Loss => train:0.39547, valid:0.39788, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 111 =======
# Loss => train:0.39102, valid:0.39273, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 112 =======
# Loss => train:0.39126, valid:0.38793, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 113 =======
# Loss => train:0.39268, valid:0.38171, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 114 =======
# Loss => train:0.39023, valid:0.38706, Elapsed time => 0.117 sec
# =======================================
#
# ======== Epoch 115 =======
# Loss => train:0.39012, valid:0.38753, Elapsed time => 0.119 sec
# =======================================
#
# ======== Epoch 116 =======
# Loss => train:0.39003, valid:0.39926, Elapsed time => 0.118 sec
# =======================================
#
# ======== Epoch 117 =======
# Loss => train:0.39277, valid:0.38140, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 118 =======
# Loss => train:0.38806, valid:0.38139, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 119 =======
# Loss => train:0.39387, valid:0.38103, Elapsed time => 0.122 sec
# =======================================
#
# ======== Epoch 120 =======
# Loss => train:0.39049, valid:0.38704, Elapsed time => 0.115 sec
# =======================================
#
# ======== Epoch 121 =======
# Loss => train:0.39299, valid:0.38423, Elapsed time => 0.132 sec
# =======================================
#
# ======== Epoch 122 =======
# Loss => train:0.39005, valid:0.38011, Elapsed time => 0.128 sec
# =======================================
#
# ======== Epoch 123 =======
# Loss => train:0.38801, valid:0.38006, Elapsed time => 0.130 sec
# =======================================
#
# ======== Epoch 124 =======
# Loss => train:0.39570, valid:0.38043, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 125 =======
# Loss => train:0.38875, valid:0.37987, Elapsed time => 0.133 sec
# =======================================
#
# ======== Epoch 126 =======
# Loss => train:0.38838, valid:0.38669, Elapsed time => 0.130 sec
# =======================================
#
# ======== Epoch 127 =======
# Loss => train:0.38824, valid:0.38796, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 128 =======
# Loss => train:0.38858, valid:0.37930, Elapsed time => 0.134 sec
# =======================================
#
# ======== Epoch 129 =======
# Loss => train:0.38921, valid:0.37797, Elapsed time => 0.132 sec
# =======================================
#
# ======== Epoch 130 =======
# Loss => train:0.39041, valid:0.37779, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 131 =======
# Loss => train:0.38418, valid:0.39031, Elapsed time => 0.127 sec
# =======================================
#
# ======== Epoch 132 =======
# Loss => train:0.39958, valid:0.37703, Elapsed time => 0.128 sec
# =======================================
#
# ======== Epoch 133 =======
# Loss => train:0.39540, valid:0.39294, Elapsed time => 0.130 sec
# =======================================
#
# ======== Epoch 134 =======
# Loss => train:0.38705, valid:0.37710, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 135 =======
# Loss => train:0.39474, valid:0.38006, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 136 =======
# Loss => train:0.39250, valid:0.39383, Elapsed time => 0.122 sec
# =======================================
#
# ======== Epoch 137 =======
# Loss => train:0.38903, valid:0.38225, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 138 =======
# Loss => train:0.38941, valid:0.39381, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 139 =======
# Loss => train:0.38724, valid:0.37981, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 140 =======
# Loss => train:0.38406, valid:0.37584, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 141 =======
# Loss => train:0.38744, valid:0.38249, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 142 =======
# Loss => train:0.38698, valid:0.37472, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 143 =======
# Loss => train:0.38401, valid:0.37945, Elapsed time => 0.118 sec
# =======================================
#
# ======== Epoch 144 =======
# Loss => train:0.38190, valid:0.38003, Elapsed time => 0.118 sec
# =======================================
#
# ======== Epoch 145 =======
# Loss => train:0.38378, valid:0.37834, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 146 =======
# Loss => train:0.38443, valid:0.40238, Elapsed time => 0.118 sec
# =======================================
#
# ======== Epoch 147 =======
# Loss => train:0.38303, valid:0.37508, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 148 =======
# Loss => train:0.38428, valid:0.37457, Elapsed time => 0.122 sec
# =======================================
#
# ======== Epoch 149 =======
# Loss => train:0.38224, valid:0.39388, Elapsed time => 0.119 sec
# =======================================
#
# ======== Epoch 150 =======
# Loss => train:0.38496, valid:0.41211, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 151 =======
# Loss => train:0.39260, valid:0.38096, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 152 =======
# Loss => train:0.38418, valid:0.37626, Elapsed time => 0.140 sec
# =======================================
#
# ======== Epoch 153 =======
# Loss => train:0.38892, valid:0.38787, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 154 =======
# Loss => train:0.38341, valid:0.38579, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 155 =======
# Loss => train:0.38692, valid:0.37373, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 156 =======
# Loss => train:0.38274, valid:0.38112, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 157 =======
# Loss => train:0.38162, valid:0.37332, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 158 =======
# Loss => train:0.38283, valid:0.37435, Elapsed time => 0.118 sec
# =======================================
#
# ======== Epoch 159 =======
# Loss => train:0.38481, valid:0.38365, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 160 =======
# Loss => train:0.38319, valid:0.37265, Elapsed time => 0.127 sec
# =======================================
#
# ======== Epoch 161 =======
# Loss => train:0.39270, valid:0.37273, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 162 =======
# Loss => train:0.38314, valid:0.37612, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 163 =======
# Loss => train:0.38425, valid:0.40117, Elapsed time => 0.139 sec
# =======================================
#
# ======== Epoch 164 =======
# Loss => train:0.38238, valid:0.37613, Elapsed time => 0.135 sec
# =======================================
#
# ======== Epoch 165 =======
# Loss => train:0.38484, valid:0.37616, Elapsed time => 0.142 sec
# =======================================
#
# ======== Epoch 166 =======
# Loss => train:0.38510, valid:0.38259, Elapsed time => 0.141 sec
# =======================================
#
# ======== Epoch 167 =======
# Loss => train:0.39276, valid:0.37256, Elapsed time => 0.143 sec
# =======================================
#
# ======== Epoch 168 =======
# Loss => train:0.38271, valid:0.37300, Elapsed time => 0.130 sec
# =======================================
#
# ======== Epoch 169 =======
# Loss => train:0.38157, valid:0.37999, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 170 =======
# Loss => train:0.38064, valid:0.37348, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 171 =======
# Loss => train:0.38203, valid:0.38098, Elapsed time => 0.140 sec
# =======================================
#
# ======== Epoch 172 =======
# Loss => train:0.39168, valid:0.37365, Elapsed time => 0.128 sec
# =======================================
#
# ======== Epoch 173 =======
# Loss => train:0.38133, valid:0.37214, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 174 =======
# Loss => train:0.38189, valid:0.38073, Elapsed time => 0.130 sec
# =======================================
#
# ======== Epoch 175 =======
# Loss => train:0.38237, valid:0.37275, Elapsed time => 0.130 sec
# =======================================
#
# ======== Epoch 176 =======
# Loss => train:0.38321, valid:0.37265, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 177 =======
# Loss => train:0.37982, valid:0.37190, Elapsed time => 0.122 sec
# =======================================
#
# ======== Epoch 178 =======
# Loss => train:0.37930, valid:0.37424, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 179 =======
# Loss => train:0.38665, valid:0.38118, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 180 =======
# Loss => train:0.38437, valid:0.37262, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 181 =======
# Loss => train:0.38111, valid:0.37838, Elapsed time => 0.132 sec
# =======================================
#
# ======== Epoch 182 =======
# Loss => train:0.38079, valid:0.38345, Elapsed time => 0.117 sec
# =======================================
#
# ======== Epoch 183 =======
# Loss => train:0.38022, valid:0.37169, Elapsed time => 0.131 sec
# =======================================
#
# ======== Epoch 184 =======
# Loss => train:0.38357, valid:0.38264, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 185 =======
# Loss => train:0.37822, valid:0.38359, Elapsed time => 0.128 sec
# =======================================
#
# ======== Epoch 186 =======
# Loss => train:0.38253, valid:0.41587, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 187 =======
# Loss => train:0.39543, valid:0.39184, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 188 =======
# Loss => train:0.38097, valid:0.37159, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 189 =======
# Loss => train:0.38046, valid:0.37630, Elapsed time => 0.127 sec
# =======================================
#
# ======== Epoch 190 =======
# Loss => train:0.38280, valid:0.37360, Elapsed time => 0.117 sec
# =======================================
#
# ======== Epoch 191 =======
# Loss => train:0.37970, valid:0.40491, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 192 =======
# Loss => train:0.38107, valid:0.37287, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 193 =======
# Loss => train:0.38468, valid:0.37193, Elapsed time => 0.127 sec
# =======================================
#
# ======== Epoch 194 =======
# Loss => train:0.38074, valid:0.37270, Elapsed time => 0.139 sec
# =======================================
#
# ======== Epoch 195 =======
# Loss => train:0.38080, valid:0.42560, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 196 =======
# Loss => train:0.38567, valid:0.37738, Elapsed time => 0.128 sec
# =======================================
#
# ======== Epoch 197 =======
# Loss => train:0.38187, valid:0.37376, Elapsed time => 0.125 sec
# =======================================
#
# ======== Epoch 198 =======
# Loss => train:0.38280, valid:0.39694, Elapsed time => 0.132 sec
# =======================================
#
# ======== Epoch 199 =======
# Loss => train:0.38603, valid:0.38153, Elapsed time => 0.140 sec
# =======================================
#
# ======== Epoch 200 =======
# Loss => train:0.38140, valid:0.37092, Elapsed time => 0.136 sec
# =======================================
#
# ======== Epoch 201 =======
# Loss => train:0.38252, valid:0.37565, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 202 =======
# Loss => train:0.38179, valid:0.41322, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 203 =======
# Loss => train:0.38477, valid:0.39425, Elapsed time => 0.136 sec
# =======================================
#
# ======== Epoch 204 =======
# Loss => train:0.38747, valid:0.37392, Elapsed time => 0.128 sec
# =======================================
#
# ======== Epoch 205 =======
# Loss => train:0.38107, valid:0.37632, Elapsed time => 0.145 sec
# =======================================
#
# ======== Epoch 206 =======
# Loss => train:0.38125, valid:0.37318, Elapsed time => 0.128 sec
# =======================================
#
# ======== Epoch 207 =======
# Loss => train:0.38289, valid:0.40967, Elapsed time => 0.138 sec
# =======================================
#
# ======== Epoch 208 =======
# Loss => train:0.38484, valid:0.37539, Elapsed time => 0.132 sec
# =======================================
#
# ======== Epoch 209 =======
# Loss => train:0.38348, valid:0.39416, Elapsed time => 0.144 sec
# =======================================
#
# ======== Epoch 210 =======
# Loss => train:0.38240, valid:0.37562, Elapsed time => 0.138 sec
# =======================================
#
# ======== Epoch 211 =======
# Loss => train:0.38040, valid:0.37713, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 212 =======
# Loss => train:0.39098, valid:0.37204, Elapsed time => 0.119 sec
# =======================================
#
# ======== Epoch 213 =======
# Loss => train:0.38184, valid:0.37127, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 214 =======
# Loss => train:0.37900, valid:0.39932, Elapsed time => 0.128 sec
# =======================================
#
# ======== Epoch 215 =======
# Loss => train:0.38152, valid:0.37151, Elapsed time => 0.126 sec
# =======================================
#
# ======== Epoch 216 =======
# Loss => train:0.39176, valid:0.37178, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 217 =======
# Loss => train:0.37763, valid:0.38446, Elapsed time => 0.128 sec
# =======================================
#
# ======== Epoch 218 =======
# Loss => train:0.38006, valid:0.37874, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 219 =======
# Loss => train:0.38128, valid:0.37163, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 220 =======
# Loss => train:0.38185, valid:0.38764, Elapsed time => 0.123 sec
# =======================================
#
# ======== Epoch 221 =======
# Loss => train:0.38084, valid:0.39973, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 222 =======
# Loss => train:0.38188, valid:0.37987, Elapsed time => 0.120 sec
# =======================================
#
# ======== Epoch 223 =======
# Loss => train:0.37895, valid:0.37308, Elapsed time => 0.124 sec
# =======================================
#
# ======== Epoch 224 =======
# Loss => train:0.37837, valid:0.37250, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 225 =======
# Loss => train:0.38368, valid:0.41419, Elapsed time => 0.134 sec
# =======================================
#
# ======== Epoch 226 =======
# Loss => train:0.38728, valid:0.37176, Elapsed time => 0.122 sec
# =======================================
#
# ======== Epoch 227 =======
# Loss => train:0.37826, valid:0.38498, Elapsed time => 0.129 sec
# =======================================
#
# ======== Epoch 228 =======
# Loss => train:0.38070, valid:0.38936, Elapsed time => 0.121 sec
# =======================================
#
# ======== Epoch 229 =======
# Loss => train:0.38263, valid:0.40212, Elapsed time => 0.127 sec
# =======================================
#
# ======== Epoch 230 =======
# Loss => train:0.38604, valid:0.37954, Elapsed time => 0.118 sec
# =======================================

# %% [markdown]
# # Learning Curve

# %%
import matplotlib.pyplot as plt 

plt.plot(train_loss_history)
plt.plot(valid_loss_history)
plt.axhline(y=min(valid_loss_history), color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# # Load best model

# %%
checkpoint = torch.load('./saved_model.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']

print(epoch, loss.item())
# Out:
# 200 0.37091705203056335

# %% [markdown]
# # Evaluation

# %%
prediction = model(X_test)
loss = criterion(prediction[:,0], y_test)

print(f"loss: {loss:.5f}")
# Out:
# loss: 0.66632

# %%
df_test.shape
# Out:
# (1826, 8)

# %%
y_test.shape
# Out:
# torch.Size([1825])

# %%
plt.figure(figsize=(15,6))
plt.plot(df_test.iloc[1:]['date'], y_test.detach().numpy())
plt.plot(df_test.iloc[1:]['date'], prediction[:,0].detach().numpy())
plt.show()
